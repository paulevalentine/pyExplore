# %%
import sympy as sp
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("../data/test.xlsx", index_col=0)

# %%
print(df.head())
# Out:
#       A  B  C
# Name
# Paul  1  2  3
# John  4  5  6
# Jim   7  8  9

# %%
df['max']=df.max(axis=1)
#df.drop('max',axis=1,inplace=True)

# %%
display(df)
# Out:
#       A   B  C   max
# Name
# Paul  1  20  3  20.0
# John  4   5  6   6.0
# Jim   7   8  9   9.0

# %%
fig, ax = plt.subplots()
ax.bar(df.index,df['A'])
ax.grid()
ax.set_xlabel('Some values')
plt.show()

# %%
df.columns.tolist()
# Out:
# ['A', 'B', 'C']
